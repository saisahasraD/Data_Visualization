# %% [markdown]
# <a href="https://colab.research.google.com/github/saisahasraD/Data_Visualization/blob/main/Linearequation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter a: "))
b = int(input("Enter b: "))
c = int(input("Enter c: "))

d = int(input("Enter d: "))
e = int(input("Enter e: "))
f = int(input("Enter f: "))

x = (c * e - b * f) / (a * e - b * d)
y = (a * f - c * d) / (a * e - b * d)

print("x =", x)
print("y =", y)
# Out:
# Enter a: 2
# Enter b: 4
# Enter c: 6
# Enter d: 7
# Enter e: 8
# Enter f: 9
# x = -1.0
# y = 2.0
